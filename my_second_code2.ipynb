# %% [markdown]
# <a href="https://colab.research.google.com/github/August2408/my_first_python_code-2/blob/main/my_second_code2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name1 = "ธีรภัทร อ่อนอารีย์"
print(f"สวัสดีครับ ผมชื่อ {name1} และนี่คือโค้ดแรกของGithub")
name2 = "ปัณณทัต กลัดแก้ว"
print(f"สวัสดีครับ ผมชื่อ {name2} และนี่คือโค้ดแรกของGithub")
# Out:
# สวัสดีครับ ผมชื่อ ธีรภัทร อ่อนอารีย์ และนี่คือโค้ดแรกของGithub
# สวัสดีครับ ผมชื่อ ปัณณทัต กลัดแก้ว และนี่คือโค้ดแรกของGithub
